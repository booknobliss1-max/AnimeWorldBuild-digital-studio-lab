# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="utf-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1" />
  <title>Cold Deities & Winter Spirits — Culturecare.online</title>
  <meta name="description" content="A concise, blog-ready roundup of cold deities, winter spirits, and frost beings. Crafted with Culturecare.online brand colors for easy publishing." />
  <style>
    :root{
      --green: #90C53D; /* 💚 */
      --teal:  #058397; /* 🩵 */
      --navy:  #002E45; /* 💙 */
      --bg: #FAFCFB;
      --card-bg: #ffffff;
      --muted: #6b7a81;
      --radius: 14px;
      --maxw: 920px;
      --accent-gradient: linear-gradient(135deg, var(--teal), var(--green));
    }

    html,body{height:100%;margin:0;background:var(--bg);font-family:Inter, system-ui, -apple-system, 'Segoe UI', Roboto, 'Helvetica Neue', Arial; color:var(--navy);}
    .container{max-width:var(--maxw);margin:36px auto;padding:28px;}
    header{display:flex;gap:18px;align-items:center}
    .brand-badge{width:64px;height:64px;border-radius:10px;background:var(--accent-gradient);display:flex;align-items:center;justify-content:center;box-shadow:0 6px 18px rgba(2,46,69,0.08);}
    .brand-badge h1{font-size:20px;color:white;margin:0}
    h1{font-size:28px;margin:0 0 6px}
    p.lead{color:var(--muted);margin:8px 0 20px;font-size:15px}

    .grid{display:grid;grid-template-columns:repeat(auto-fit,minmax(220px,1fr));gap:16px}
    .card{background:var(--card-bg);padding:16px;border-radius:var(--radius);box-shadow:0 6px 16px rgba(2,46,69,0.04);border:1px solid rgba(2,46,69,0.04)}
    .card h3{margin:0 0 6px;font-size:18px}
    .card .meta{font-size:13px;color:var(--muted);margin-bottom:8px}
    .tag{display:inline-block;padding:6px 10px;border-radius:999px;background:linear-gradient(90deg, rgba(144,197,61,0.12), rgba(5,131,151,0.08));font-size:12px;color:var(--navy);}

    .section-title{display:flex;align-items:center;gap:12px;margin:22px 0 8px}
    .section-title h2{margin:0;font-size:20px}

    .compare{display:flex;gap:12px;flex-wrap:wrap}
    .pill{padding:10px 12px;border-radius:999px;background:#f0f6f6;border:1px solid rgba(2,46,69,0.03);font-size:13px}

    footer{margin-top:26px;color:var(--muted);font-size:13px;display:flex;justify-content:space-between;align-items:center}
    .cta{background:var(--navy);color:white;padding:10px 14px;border-radius:10px;text-decoration:none}

    @media print{body{background:white} .container{box-shadow:none} .brand-badge{display:none}}
  </style>
</head>
<body>
  <div class="container">
    <header>
      <div class="brand-badge" aria-hidden="true">
        <h1>CC</h1>
      </div>
      <div>
        <h1>Cold Deities & Winter Spirits</h1>
        <p class="lead">A culturally respectful roundup of winter-aligned gods, spirits, and frost beings — curated for storytelling, worldbuilding, and cultural exploration.</p>
      </div>
    </header>

    <section class="card" aria-labelledby="overview">
      <h2 id="overview">Overview</h2>
      <p class="meta">Elemental theme: <span class="tag">Cold / Ice / Winter</span> · Tone: <span class="tag">Mythic · Respectful · Visual</span></p>
      <p>These figures embody stillness, endurance, clarity, and the liminality of winter. Use them as character seeds, symbolic motifs, or community-facing educational content. Below are quick, copy-ready cards you can drop into your blog post.</p>
    </section>

    <div class="section-title">
      <h2>Featured Winter Figures</h2>
      <div class="compare">
        <span class="pill">Norse</span>
        <span class="pill">Slavic</span>
        <span class="pill">Japanese</span>
        <span class="pill">Inuit / Arctic</span>
        <span class="pill">Celtic</span>
      </div>
    </div>

    <div class="grid">
      <article class="card">
        <h3>Skadi — Norse Goddess of Winter</h3>
        <p class="meta">Role: Huntress · Domain: Mountains & Snow</p>
        <p>Skadi is a resilient mountain goddess associated with skiing, hunting, and the harsh beauty of alpine cold. She represents independence and the austere endurance of winter landscapes.</p>
      </article>

      <article class="card">
        <h3>Jotnar — Frost Giants (Norse)</h3>
        <p class="meta">Role: Primordial beings · Domain: Ice & Rime</p>
        <p>Jotnar personify primeval frost and chaotic cold. Often antagonistic to the gods, they are embodiments of winter’s raw and ancient power.</p>
      </article>

      <article class="card">
        <h3>The Cailleach — Celtic Winter Hag</h3>
        <p class="meta">Role: Land-shaper · Domain: Winter & Stone</p>
        <p>The Cailleach is a winter deity who creates mountains and freezes the land. She rules the winter months and embodies the generative, destructive cycles of seasonal change.</p>
      </article>

      <article class="card">
        <h3>Morana / Marzanna — Slavic Goddess of Winter</h3>
        <p class="meta">Role: Death & Winter · Domain: Frost & Stillness</p>
        <p>Morana symbolizes the frozen hush of winter and the necessary rest before spring. Historically, her effigies were burned or drowned to welcome the thaw and rebirth of spring.</p>
      </article>

      <article class="card">
        <h3>Boreas & Khione — Greek North Wind & Snow</h3>
        <p class="meta">Role: Wind & Snow · Domain: North Winds, Snowfalls</p>
        <p>Boreas is the fierce north wind; his daughter Khione personifies snow. Together they bring the crisp and often violent weather of winter to the Greek world.</p>
      </article>

      <article class="card">
        <h3>Yuki-onna — Japanese Snow Woman</h3>
        <p class="meta">Role: Spirit of Snow · Domain: Blizzards & Cold</p>
        <p>The spectral Yuki-onna appears during snowstorms: beautiful, pale, and dangerous. In folklore she can be both tragic and lethal — a personification of winter’s deceptive stillness.</p>
      </article>

      <article class="card">
        <h3>Sedna — Inuit Mistress of the Cold Depths</h3>
        <p class="meta">Role: Sea-mother · Domain: Arctic Waters & Marine Life</p>
        <p>Sedna rules creatures beneath the ice and holds complex stories of transformation, respect, and the balance between human communities and the cold sea.</p>
      </article>

      <article class="card">
        <h3>Mahaha — Inuit Frost Trickster</h3>
        <p class="meta">Role: Frost Demon · Domain: Arctic Cold</p>
        <p>Mahaha is a slender, laughing frost spirit who brings deadly cold. His tales warn travelers about the merciless edges of winter.</p>
      </article>
    </div>

    <section class="card" aria-labelledby="use">
      <h2 id="use">Ways to Use This Content</h2>
      <ul>
        <li>Drop individual cards as <strong>mini-sections</strong> inside a longer blog post.</li>
        <li>Create a visual <strong>character deck</strong> for social posts (each card is already short & shareable).</li>
        <li>Pair the cards with field images or local oral-history quotes for cultural-context posts.</li>
      </ul>
    </section>

    <footer>
      <div>Made with <span style="color:var(--green)">💚</span> <span style="color:var(--teal)">🩵</span> <span style="color:var(--navy)">💙</span> Culturecare.online</div>
      <div><a class="cta" href="#">Copy HTML</a></div>
    </footer>
  </div>
</body>
</html>
